# %% [markdown]
# # 1. [Opt] Check GPU Type

# %%
# Check GPU Type
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
# Out:
# Thu Dec 15 22:12:21 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    25W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 2. Git Clone from Github Repository to root directory
# At Colab, location is "/content/".
#
# Using `$ git clone https://github.com/lainyzine/git-clone.git` will load the Github repository with the name of the repository. With Colab, it can be convenient to work in the root directory. You can use the command to call the root directory as shown below.
#
# According to the Github repository, we can use `! git pull origin main` or `! Just use git pull origin master`.

# %%
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_31_Pytorch_Complex_Yolo_Yolov3.git
# ! git pull origin master
! git pull origin main
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 1160, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 1160 (delta 25), reused 0 (delta 0), pack-reused 1113
# Receiving objects: 100% (1160/1160), 734.63 MiB | 16.51 MiB/s, done.
# Resolving deltas: 100% (220/220), done.
# From https://github.com/RichardMinsooGo-ML/Bible_3_31_Pytorch_Complex_Yolo_Yolov3
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Checking out files: 100% (1107/1107), done.

# %% [markdown]
# # 3. import clear_output

# %%
from IPython.display import clear_output 
clear_output()

# %% [markdown]
# # 4. Kitti dataset download from Auther's Github repository

# %%
# !pip install --upgrade --no-cache-dir gdown

# Due to the size of data it was separated with two files
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz'
output_name = 'Complex-YOLOv4_Data_1.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/17NrrnO-Uw_foiGlPtXXr3IalQUhmZxGz/view?usp=sharing

# !unzip -o /content/Complex-YOLOv4_Data_1.zip -d /content/
clear_output()
# !rm /content/Complex-YOLOv4_Data_1.zip

# %%
# Due to the size of data it was separated with two files
google_path = 'https://drive.google.com/uc?id='
file_id = '1_WIldJYOrxmVVSjm0no10Llg8vi3VstE'
output_name = 'Complex-YOLOv4_Data_2.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1_WIldJYOrxmVVSjm0no10Llg8vi3VstE/view?usp=sharing

# !unzip -o /content/Complex-YOLOv4_Data_2.zip -d /content/
clear_output()
# !rm /content/Complex-YOLOv4_Data_2.zip

# %% [markdown]
# # 5. [Opt] Check Memory Space

# %%
# Memory Space
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# # 6. install terminaltables for Ascii Table print

# %%
# !pip install terminaltables
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables
# Successfully installed terminaltables-3.1.10

# %% [markdown]
# # 7. Download Darknet Weights

# %%
# Download Darknet Weights
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
! wget https://pjreddie.com/media/files/yolov3.weights
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import shutil
shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov3.weights", "/content/checkpoints")
# shutil.move("/content/yolov4-tiny.weights", "/content/tmp")
# shutil.move("/content/yolov4.weights", "/content/tmp") 
shutil.rmtree("sample_data")
# Out:
# --2022-12-15 22:21:37--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  11.8MB/s    in 2.9s
#
# 2022-12-15 22:21:41 (11.8 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-12-15 22:21:41--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  17.6MB/s    in 15s
#
# 2022-12-15 22:21:57 (16.0 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %% [markdown]
# # 8. Complex Yolo - Yolo V3 Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1jpaDXJcBLf4s3JBYrmapkTQ9OCeGmoQI'
output_name = 'Complex_yolo_yolo_v3.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1jpaDXJcBLf4s3JBYrmapkTQ9OCeGmoQI/view?usp=sharing

shutil.move("/content/Complex_yolo_yolo_v3.pth", "./checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jpaDXJcBLf4s3JBYrmapkTQ9OCeGmoQI
# To: /content/Complex_yolo_yolo_v3.pth
# 100%|██████████| 246M/246M [00:05<00:00, 48.4MB/s]
# './checkpoints/Complex_yolo_yolo_v3.pth'

# %% [markdown]
# # 9. Complex Yolo - Yolo V3-tiny Pre-Trained Weight gdown from Auther's GDrive

# %%
google_path = 'https://drive.google.com/uc?id='
file_id = '1Mukg7aZ3C5ZWFhkS5r1wmL1tgWXsTxS6'
output_name = 'Complex_yolo_yolo_v3_tiny.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1Mukg7aZ3C5ZWFhkS5r1wmL1tgWXsTxS6/view?usp=sharing

shutil.move("/content/Complex_yolo_yolo_v3_tiny.pth", "./checkpoints")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Mukg7aZ3C5ZWFhkS5r1wmL1tgWXsTxS6
# To: /content/Complex_yolo_yolo_v3_tiny.pth
# 100%|██████████| 34.8M/34.8M [00:01<00:00, 18.7MB/s]
# './checkpoints/Complex_yolo_yolo_v3_tiny.pth'

# %%
# from google.colab import drive 
# drive.mount('/content/gdrive/')

# %% [markdown]
# # 10. Train YOLO v3 from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 4 --pretrained_path /content/checkpoints/Complex_yolo_yolo_v3.pth --save_path /content/checkpoints/Complex_yolo_yolo_v3.pth
# Out:
# cuda
# Load TRAIN samples from dataset/kitti/training
# Done: total TRAIN samples 5763
# /content/checkpoints/Complex_yolo_yolo_v3.pth
# Trained pytorch weight loaded!
# 1441
#  33% 479/1441 [04:52<10:14,  1.56it/s]
# ---- [Epoch 1/3, Batch 480/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 20           | 40           | 80           |
# | loss       | 0.048333     | 0.215392     | 0.103346     |
# | loss_x     | 0.002892     | 0.004066     | 0.010507     |
# | loss_y     | 0.001656     | 0.002107     | 0.006741     |
# | loss_w     | 0.000800     | 0.002396     | 0.001677     |
# | loss_h     | 0.003735     | 0.002974     | 0.003546     |
# | loss_im    | 0.001634     | 0.011847     | 0.001634     |
# | loss_re    | 0.000946     | 0.006052     | 0.000965     |
# | loss_obj   | 0.036218     | 0.181260     | 0.078050     |
# | loss_cls   | 0.000006     | 0.000441     | 0.000007     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.992583     | 0.974467     | 0.986113     |
# | conf_noobj | 0.000176     | 0.000797     | 0.000239     |
# +------------+--------------+--------------+--------------+
# Total loss 0.36707064509391785
# ---- ETA 0:09:46.780273
#  67% 959/1441 [09:35<05:56,  1.35it/s]
# ---- [Epoch 1/3, Batch 960/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 22           | 44           | 88           |
# | loss       | 0.691433     | 0.399462     | 0.214138     |
# | loss_x     | 0.002850     | 0.011822     | 0.009952     |
# | loss_y     | 0.016054     | 0.012720     | 0.016901     |
# | loss_w     | 0.001197     | 0.003300     | 0.002972     |
# | loss_h     | 0.002299     | 0.006645     | 0.001340     |
# | loss_im    | 0.003946     | 0.020770     | 0.009301     |
# | loss_re    | 0.228208     | 0.015380     | 0.002027     |
# | loss_obj   | 0.415990     | 0.314793     | 0.171253     |
# | loss_cls   | 0.000028     | 0.000533     | 0.000004     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.885030     | 0.914811     | 0.954453     |
# | conf_noobj | 0.000699     | 0.001173     | 0.000411     |
# +------------+--------------+--------------+--------------+
# Total loss 1.3050323724746704
# ---- ETA 0:04:48.523754
# 100% 1439/1441 [14:24<00:01,  1.34it/s]
# ---- [Epoch 1/3, Batch 1440/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 22           | 44           | 88           |
# | loss       | 0.426158     | 0.592094     | 0.274003     |
# | loss_x     | 0.005194     | 0.009972     | 0.011627     |
# | loss_y     | 0.013597     | 0.022311     | 0.012927     |
# | loss_w     | 0.004423     | 0.006595     | 0.004187     |
# | loss_h     | 0.005586     | 0.012763     | 0.003108     |
# | loss_im    | 0.079565     | 0.020255     | 0.014684     |
# | loss_re    | 0.028114     | 0.023839     | 0.028703     |
# | loss_obj   | 0.255532     | 0.477566     | 0.195869     |
# | loss_cls   | 0.000034     | 0.007849     | 0.000111     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.913584     | 0.840131     | 0.951445     |
# | conf_noobj | 0.000933     | 0.001501     | 0.000577     |
# +------------+--------------+--------------+--------------+
# Total loss 1.2922550439834595
# ---- ETA 0:00:00.600733
# 100% 1441/1441 [14:25<00:00,  1.66it/s]
# Current epoch loss : 0.87738 Saved at /content/checkpoints/Complex_yolo_yolo_v3.pth
# 1441
#  33% 479/1441 [04:43<10:11,  1.57it/s]
# ---- [Epoch 2/3, Batch 480/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 21           | 42           | 84           |
# | loss       | 0.449596     | 0.603891     | 0.195417     |
# | loss_x     | 0.002835     | 0.007024     | 0.006543     |
# | loss_y     | 0.005471     | 0.009426     | 0.009560     |
# | loss_w     | 0.001729     | 0.005632     | 0.002331     |
# | loss_h     | 0.003892     | 0.008209     | 0.005690     |
# | loss_im    | 0.009485     | 0.018374     | 0.007340     |
# | loss_re    | 0.005857     | 0.011934     | 0.002089     |
# | loss_obj   | 0.416033     | 0.534094     | 0.161368     |
# | loss_cls   | 0.000321     | 0.004361     | 0.000176     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.891153     | 0.848640     | 0.958113     |
# | conf_noobj | 0.001381     | 0.001552     | 0.000482     |
# +------------+--------------+--------------+--------------+
# Total loss 1.2489049434661865
# ---- ETA 0:38:22.784721
#  67% 959/1441 [09:32<04:16,  1.88it/s]
# ---- [Epoch 2/3, Batch 960/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 18           | 36           | 72           |
# | loss       | 0.437248     | 0.285586     | 0.064213     |
# | loss_x     | 0.006522     | 0.006603     | 0.009026     |
# | loss_y     | 0.002803     | 0.005487     | 0.007181     |
# | loss_w     | 0.008841     | 0.002462     | 0.002216     |
# | loss_h     | 0.025063     | 0.010671     | 0.001799     |
# | loss_im    | 0.000496     | 0.029118     | 0.002051     |
# | loss_re    | 0.002027     | 0.003489     | 0.000187     |
# | loss_obj   | 0.332921     | 0.223998     | 0.041556     |
# | loss_cls   | 0.056615     | 0.001378     | 0.000011     |
# | cls_acc    | 92.86%       | 100.00%      | 100.00%      |
# | conf_obj   | 0.892426     | 0.952411     | 0.993687     |
# | conf_noobj | 0.000926     | 0.000963     | 0.000190     |
# +------------+--------------+--------------+--------------+
# Total loss 0.7870468497276306
# ---- ETA 0:12:01.209747
# 100% 1439/1441 [14:13<00:00,  2.18it/s]
# ---- [Epoch 2/3, Batch 1440/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 0.147614     | 0.261411     | 0.149259     |
# | loss_x     | 0.002495     | 0.005964     | 0.010591     |
# | loss_y     | 0.004557     | 0.007320     | 0.026782     |
# | loss_w     | 0.003671     | 0.006095     | 0.004551     |
# | loss_h     | 0.006106     | 0.009220     | 0.002745     |
# | loss_im    | 0.001206     | 0.021354     | 0.002629     |
# | loss_re    | 0.006128     | 0.002893     | 0.001340     |
# | loss_obj   | 0.122655     | 0.204415     | 0.100503     |
# | loss_cls   | 0.000154     | 0.001063     | 0.000003     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.945030     | 0.955691     | 0.966713     |
# | conf_noobj | 0.000481     | 0.000945     | 0.000297     |
# +------------+--------------+--------------+--------------+
# Total loss 0.5582842230796814
# ---- ETA 0:00:01.194319
# 100% 1441/1441 [14:13<00:00,  1.69it/s]
# Current epoch loss : 0.80638 Saved at /content/checkpoints/Complex_yolo_yolo_v3.pth
# 1441
#  33% 479/1441 [04:35<09:56,  1.61it/s]
# ---- [Epoch 3/3, Batch 480/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 19           | 38           | 76           |
# | loss       | 0.168023     | 0.196629     | 0.097483     |
# | loss_x     | 0.002928     | 0.006362     | 0.005537     |
# | loss_y     | 0.001688     | 0.015780     | 0.012904     |
# | loss_w     | 0.006081     | 0.013140     | 0.005621     |
# | loss_h     | 0.002177     | 0.007203     | 0.001623     |
# | loss_im    | 0.000958     | 0.005315     | 0.001399     |
# | loss_re    | 0.005369     | 0.001533     | 0.000615     |
# | loss_obj   | 0.148253     | 0.146176     | 0.069114     |
# | loss_cls   | 0.000087     | 0.000218     | 0.000003     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.944713     | 0.944706     | 0.988252     |
# | conf_noobj | 0.000456     | 0.000451     | 0.000241     |
# +------------+--------------+--------------+--------------+
# Total loss 0.4621348977088928
# ---- ETA 1:06:38.670913
#  67% 959/1441 [09:11<03:40,  2.18it/s]
# ---- [Epoch 3/3, Batch 960/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 0.176965     | 0.287207     | 0.101058     |
# | loss_x     | 0.008265     | 0.006467     | 0.006194     |
# | loss_y     | 0.022299     | 0.007992     | 0.015048     |
# | loss_w     | 0.005236     | 0.009103     | 0.004828     |
# | loss_h     | 0.008620     | 0.009554     | 0.001906     |
# | loss_im    | 0.004683     | 0.011649     | 0.001489     |
# | loss_re    | 0.007534     | 0.006485     | 0.001036     |
# | loss_obj   | 0.113774     | 0.227930     | 0.069614     |
# | loss_cls   | 0.000247     | 0.000294     | 0.000374     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.970512     | 0.932568     | 0.984937     |
# | conf_noobj | 0.000561     | 0.001116     | 0.000313     |
# +------------+--------------+--------------+--------------+
# Total loss 0.5652299523353577
# ---- ETA 0:18:58.543432
# 100% 1439/1441 [14:01<00:01,  1.59it/s]
# ---- [Epoch 3/3, Batch 1440/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 20           | 40           | 80           |
# | loss       | 0.962272     | 0.477486     | 0.216800     |
# | loss_x     | 0.001133     | 0.005107     | 0.007540     |
# | loss_y     | 0.005402     | 0.011496     | 0.021223     |
# | loss_w     | 0.001258     | 0.007619     | 0.002198     |
# | loss_h     | 0.005416     | 0.013225     | 0.003457     |
# | loss_im    | 0.008176     | 0.017958     | 0.006909     |
# | loss_re    | 0.108777     | 0.030100     | 0.014334     |
# | loss_obj   | 0.790490     | 0.361189     | 0.146180     |
# | loss_cls   | 0.000040     | 0.000676     | 0.000000     |
# | cls_acc    | 100.00%      | 100.00%      | 100.00%      |
# | conf_obj   | 0.847225     | 0.895665     | 0.945330     |
# | conf_noobj | 0.000932     | 0.001239     | 0.000327     |
# +------------+--------------+--------------+--------------+
# Total loss 1.6565579175949097
# ---- ETA 0:00:01.779579
# 100% 1441/1441 [14:02<00:00,  1.71it/s]
# Current epoch loss : 0.80230 Saved at /content/checkpoints/Complex_yolo_yolo_v3.pth
#
# ---- Evaluating Model ----
# Load EVAL samples from dataset/kitti/training
# Done: total EVAL samples 1481
# Detecting objects: 100% 371/371 [02:24<00:00,  2.56it/s]
# Computing AP: 100% 3/3 [00:00<00:00, 173.10it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | Car        | 0.97284 |
# | 1     | Pedestrian | 0.75256 |
# | 2     | Cyclist    | 0.85907 |
# +-------+------------+---------+
# ---- mAP 0.8614936038210109

# %% [markdown]
# # 11. Train YOLO v3 from Darknet Weights

# %%
! python train.py --num_epochs 3 --batch_size 4 --pretrained_path /content/checkpoints/yolov3.weights --save_path /content/checkpoints/Complex_yolo_yolo_v3.pth
# Out:
# cuda
# Load TRAIN samples from dataset/kitti/training
# Done: total TRAIN samples 5763
# /content/checkpoints/yolov3.weights
# Darknet weight loaded!
# 1441
#  33% 479/1441 [04:48<10:33,  1.52it/s]
# ---- [Epoch 1/3, Batch 480/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 20           | 40           | 80           |
# | loss       | 7.270803     | 23.422480    | 36.032383    |
# | loss_x     | 0.086044     | 0.110717     | 0.085617     |
# | loss_y     | 0.103520     | 0.057323     | 0.058351     |
# | loss_w     | 0.013559     | 0.086958     | 0.051236     |
# | loss_h     | 0.010528     | 0.074161     | 0.085693     |
# | loss_im    | 0.032683     | 0.218975     | 0.146646     |
# | loss_re    | 1.301022     | 0.970738     | 0.621014     |
# | loss_obj   | 5.299071     | 21.219013    | 34.411015    |
# | loss_cls   | 0.170751     | 0.407840     | 0.340675     |
# | cls_acc    | 86.36%       | 86.36%       | 82.61%       |
# | conf_obj   | 0.014522     | 0.343515     | 0.495622     |
# | conf_noobj | 0.010057     | 0.181666     | 0.285396     |
# +------------+--------------+--------------+--------------+
# Total loss 66.72566223144531
# ---- ETA 0:09:39.288604
#  67% 959/1441 [09:20<04:03,  1.98it/s]
# ---- [Epoch 1/3, Batch 960/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 7.997191     | 22.853453    | 35.384747    |
# | loss_x     | 0.097648     | 0.039951     | 0.040651     |
# | loss_y     | 0.111971     | 0.081330     | 0.097947     |
# | loss_w     | 0.058595     | 0.017256     | 0.024534     |
# | loss_h     | 0.128391     | 0.019954     | 0.093004     |
# | loss_im    | 0.169199     | 0.222448     | 0.114794     |
# | loss_re    | 1.330706     | 0.873258     | 0.437568     |
# | loss_obj   | 5.617467     | 21.013575    | 34.127178    |
# | loss_cls   | 0.219310     | 0.327917     | 0.279003     |
# | cls_acc    | 70.00%       | 100.00%      | 90.00%       |
# | conf_obj   | 0.009786     | 0.331972     | 0.530637     |
# | conf_noobj | 0.009292     | 0.179845     | 0.283898     |
# +------------+--------------+--------------+--------------+
# Total loss 66.23538970947266
# ---- ETA 0:04:41.057489
# 100% 1439/1441 [14:09<00:01,  1.62it/s]
# ---- [Epoch 1/3, Batch 1440/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 18           | 36           | 72           |
# | loss       | 7.317246     | 23.712748    | 36.094700    |
# | loss_x     | 0.097157     | 0.061327     | 0.064967     |
# | loss_y     | 0.067764     | 0.089428     | 0.088010     |
# | loss_w     | 0.112976     | 0.115818     | 0.019333     |
# | loss_h     | 0.206767     | 0.221341     | 0.082942     |
# | loss_im    | 0.273932     | 0.706752     | 0.608966     |
# | loss_re    | 0.877545     | 0.695302     | 0.394202     |
# | loss_obj   | 5.269490     | 21.123568    | 34.261890    |
# | loss_cls   | 0.210002     | 0.434654     | 0.305406     |
# | cls_acc    | 93.75%       | 81.25%       | 100.00%      |
# | conf_obj   | 0.012324     | 0.324178     | 0.484270     |
# | conf_noobj | 0.008437     | 0.180117     | 0.283939     |
# +------------+--------------+--------------+--------------+
# Total loss 67.12469482421875
# ---- ETA 0:00:00.589966
# 100% 1441/1441 [14:10<00:00,  1.70it/s]
# Current epoch loss : 73.69174 Saved at /content/checkpoints/Complex_yolo_yolo_v3.pth
# 1441
#  33% 479/1441 [04:44<08:27,  1.89it/s]
# ---- [Epoch 2/3, Batch 480/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 19           | 38           | 76           |
# | loss       | 6.749722     | 22.812920    | 35.443043    |
# | loss_x     | 0.052999     | 0.051411     | 0.102919     |
# | loss_y     | 0.094665     | 0.072737     | 0.091142     |
# | loss_w     | 0.015629     | 0.022879     | 0.014760     |
# | loss_h     | 0.032253     | 0.045196     | 0.072205     |
# | loss_im    | 0.211927     | 0.215098     | 0.108944     |
# | loss_re    | 0.748456     | 0.942100     | 0.476342     |
# | loss_obj   | 5.223450     | 20.859262    | 34.098244    |
# | loss_cls   | 0.086967     | 0.322392     | 0.227398     |
# | cls_acc    | 100.00%      | 100.00%      | 92.31%       |
# | conf_obj   | 0.014517     | 0.412395     | 0.572742     |
# | conf_noobj | 0.009625     | 0.180330     | 0.284240     |
# +------------+--------------+--------------+--------------+
# Total loss 65.00568389892578
# ---- ETA 0:37:53.347141
#  67% 959/1441 [09:21<04:19,  1.86it/s]
# ---- [Epoch 2/3, Batch 960/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 20           | 40           | 80           |
# | loss       | 7.385750     | 23.642506    | 36.354252    |
# | loss_x     | 0.089657     | 0.081238     | 0.075787     |
# | loss_y     | 0.098255     | 0.088083     | 0.062733     |
# | loss_w     | 0.016287     | 0.028720     | 0.019546     |
# | loss_h     | 0.066909     | 0.126634     | 0.126650     |
# | loss_im    | 0.502997     | 0.884192     | 0.787558     |
# | loss_re    | 0.783668     | 0.665956     | 0.393858     |
# | loss_obj   | 5.384557     | 21.125477    | 34.345665    |
# | loss_cls   | 0.167911     | 0.373154     | 0.292017     |
# | cls_acc    | 95.00%       | 90.00%       | 95.00%       |
# | conf_obj   | 0.013164     | 0.333228     | 0.458485     |
# | conf_noobj | 0.009997     | 0.180787     | 0.284574     |
# +------------+--------------+--------------+--------------+
# Total loss 67.38250732421875
# ---- ETA 0:11:47.709339
# 100% 1439/1441 [14:01<00:01,  1.62it/s]
# ---- [Epoch 2/3, Batch 1440/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 22           | 44           | 88           |
# | loss       | 7.837431     | 22.865982    | 35.888805    |
# | loss_x     | 0.140809     | 0.105368     | 0.056676     |
# | loss_y     | 0.094973     | 0.073349     | 0.084679     |
# | loss_w     | 0.055394     | 0.043265     | 0.052878     |
# | loss_h     | 0.066256     | 0.099698     | 0.249945     |
# | loss_im    | 0.575427     | 0.218476     | 0.189050     |
# | loss_re    | 1.080636     | 0.636071     | 0.348995     |
# | loss_obj   | 5.506874     | 21.121422    | 34.404312    |
# | loss_cls   | 0.084221     | 0.321383     | 0.290787     |
# | cls_acc    | 100.00%      | 96.00%       | 100.00%      |
# | conf_obj   | 0.015768     | 0.325089     | 0.438023     |
# | conf_noobj | 0.013321     | 0.180264     | 0.284350     |
# +------------+--------------+--------------+--------------+
# Total loss 66.59221649169922
# ---- ETA 0:00:01.175645
# 100% 1441/1441 [14:02<00:00,  1.71it/s]
# Current epoch loss : 66.87437 Saved at /content/checkpoints/Complex_yolo_yolo_v3.pth
# 1441
#  33% 479/1441 [04:36<09:11,  1.74it/s]
# ---- [Epoch 3/3, Batch 480/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 17           | 34           | 68           |
# | loss       | 7.367824     | 23.472681    | 36.000210    |
# | loss_x     | 0.097266     | 0.069314     | 0.097567     |
# | loss_y     | 0.101616     | 0.078476     | 0.086998     |
# | loss_w     | 0.048151     | 0.043701     | 0.008742     |
# | loss_h     | 0.147796     | 0.181733     | 0.066044     |
# | loss_im    | 0.327788     | 0.306208     | 0.214049     |
# | loss_re    | 0.843751     | 0.970332     | 0.678072     |
# | loss_obj   | 5.369137     | 21.139469    | 34.277775    |
# | loss_cls   | 0.200420     | 0.422723     | 0.319339     |
# | cls_acc    | 92.31%       | 80.77%       | 96.30%       |
# | conf_obj   | 0.011217     | 0.309515     | 0.460910     |
# | conf_noobj | 0.008361     | 0.180048     | 0.284010     |
# +------------+--------------+--------------+--------------+
# Total loss 66.84071350097656
# ---- ETA 1:05:46.298813
#  67% 959/1441 [09:13<04:30,  1.78it/s]
# ---- [Epoch 3/3, Batch 960/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 17           | 34           | 68           |
# | loss       | 7.790260     | 23.641472    | 36.185066    |
# | loss_x     | 0.065500     | 0.070238     | 0.084437     |
# | loss_y     | 0.083870     | 0.086805     | 0.092892     |
# | loss_w     | 0.066368     | 0.099702     | 0.018268     |
# | loss_h     | 0.289548     | 0.314997     | 0.143417     |
# | loss_im    | 0.537309     | 0.442293     | 0.435077     |
# | loss_re    | 0.958439     | 0.655492     | 0.453780     |
# | loss_obj   | 5.357612     | 21.248663    | 34.392033    |
# | loss_cls   | 0.183790     | 0.467577     | 0.330568     |
# | cls_acc    | 94.74%       | 85.00%       | 100.00%      |
# | conf_obj   | 0.013229     | 0.284211     | 0.416082     |
# | conf_noobj | 0.009500     | 0.180325     | 0.284136     |
# +------------+--------------+--------------+--------------+
# Total loss 67.6167984008789
# ---- ETA 0:18:46.325405
# 100% 1439/1441 [13:50<00:00,  2.17it/s]
# ---- [Epoch 3/3, Batch 1440/1441] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 16           | 32           | 64           |
# | loss       | 7.163095     | 23.149277    | 35.725307    |
# | loss_x     | 0.066845     | 0.063221     | 0.095744     |
# | loss_y     | 0.087431     | 0.076122     | 0.082329     |
# | loss_w     | 0.038196     | 0.011588     | 0.011358     |
# | loss_h     | 0.099566     | 0.020484     | 0.025132     |
# | loss_im    | 0.279790     | 0.460441     | 0.403885     |
# | loss_re    | 0.669933     | 0.786956     | 0.415533     |
# | loss_obj   | 5.440678     | 21.100573    | 34.229294    |
# | loss_cls   | 0.255619     | 0.350279     | 0.257970     |
# | cls_acc    | 60.87%       | 100.00%      | 100.00%      |
# | conf_obj   | 0.009429     | 0.325535     | 0.483004     |
# | conf_noobj | 0.007519     | 0.180305     | 0.284057     |
# +------------+--------------+--------------+--------------+
# Total loss 66.03767395019531
# ---- ETA 0:00:01.753120
# 100% 1441/1441 [13:51<00:00,  1.73it/s]
# Current epoch loss : 67.78725 Saved at /content/checkpoints/Complex_yolo_yolo_v3.pth
#
# ---- Evaluating Model ----
# Load EVAL samples from dataset/kitti/training
# Done: total EVAL samples 1481
# Detecting objects: 100% 371/371 [02:44<00:00,  2.25it/s]
# Computing AP: 100% 3/3 [00:00<00:00, 79.67it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | Car        | 0.21361 |
# | 1     | Pedestrian | 0.00000 |
# | 2     | Cyclist    | 0.00000 |
# +-------+------------+---------+
# ---- mAP 0.0712040883465097

# %% [markdown]
# # 12. Train YOLO v3-tiny from Pre-trained Weights

# %%
! python train.py --num_epochs 3 --batch_size 16 --model_def /content/config/complex_yolov3_tiny.cfg --pretrained_path /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth --save_path /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# Out:
# cuda
# Load TRAIN samples from dataset/kitti/training
# Done: total TRAIN samples 5763
# /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# Trained pytorch weight loaded!
# 361
#  33% 119/361 [02:10<04:10,  1.03s/it]
# ---- [Epoch 1/3, Batch 120/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 0.415179     | 0.403404     |
# | loss_x     | 0.010190     | 0.013126     |
# | loss_y     | 0.007901     | 0.013701     |
# | loss_w     | 0.005404     | 0.008193     |
# | loss_h     | 0.005928     | 0.012878     |
# | loss_im    | 0.021096     | 0.017918     |
# | loss_re    | 0.031856     | 0.018357     |
# | loss_obj   | 0.322908     | 0.300787     |
# | loss_cls   | 0.000721     | 0.002829     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.912322     | 0.915805     |
# | conf_noobj | 0.001397     | 0.001238     |
# +------------+--------------+--------------+
# Total loss 0.8185827732086182
# ---- ETA 0:04:23.625748
#  66% 239/361 [04:19<02:11,  1.08s/it]
# ---- [Epoch 1/3, Batch 240/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 17           | 34           |
# | loss       | 0.489913     | 0.737741     |
# | loss_x     | 0.007405     | 0.013745     |
# | loss_y     | 0.025015     | 0.021416     |
# | loss_w     | 0.003381     | 0.006571     |
# | loss_h     | 0.006251     | 0.009390     |
# | loss_im    | 0.032230     | 0.035924     |
# | loss_re    | 0.018338     | 0.016787     |
# | loss_obj   | 0.373677     | 0.611320     |
# | loss_cls   | 0.000186     | 0.002142     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.872565     | 0.837817     |
# | conf_noobj | 0.000745     | 0.001505     |
# +------------+--------------+--------------+
# Total loss 1.227653980255127
# ---- ETA 0:02:11.376494
#  99% 359/361 [06:31<00:02,  1.08s/it]
# ---- [Epoch 1/3, Batch 360/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 22           | 44           |
# | loss       | 0.706435     | 0.582171     |
# | loss_x     | 0.006347     | 0.019171     |
# | loss_y     | 0.008097     | 0.019515     |
# | loss_w     | 0.006181     | 0.015256     |
# | loss_h     | 0.007398     | 0.016655     |
# | loss_im    | 0.022076     | 0.010058     |
# | loss_re    | 0.012282     | 0.012892     |
# | loss_obj   | 0.623414     | 0.474813     |
# | loss_cls   | 0.004987     | 0.006813     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.830040     | 0.863072     |
# | conf_noobj | 0.001478     | 0.001294     |
# +------------+--------------+--------------+
# Total loss 1.2886061668395996
# ---- ETA 0:00:01.090514
# 100% 361/361 [06:32<00:00,  1.09s/it]
# Current epoch loss : 1.18070 Saved at /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# 361
#  33% 119/361 [02:09<04:36,  1.14s/it]
# ---- [Epoch 2/3, Batch 120/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 20           | 40           |
# | loss       | 0.381032     | 0.468970     |
# | loss_x     | 0.007057     | 0.015809     |
# | loss_y     | 0.009297     | 0.016553     |
# | loss_w     | 0.005632     | 0.011313     |
# | loss_h     | 0.007644     | 0.010864     |
# | loss_im    | 0.018499     | 0.015135     |
# | loss_re    | 0.008893     | 0.008937     |
# | loss_obj   | 0.307951     | 0.375180     |
# | loss_cls   | 0.000102     | 0.001986     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.911658     | 0.898294     |
# | conf_noobj | 0.001139     | 0.001308     |
# +------------+--------------+--------------+
# Total loss 0.8500024080276489
# ---- ETA 0:17:30.838494
#  66% 239/361 [04:20<02:22,  1.16s/it]
# ---- [Epoch 2/3, Batch 240/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 22           | 44           |
# | loss       | 0.476608     | 0.433713     |
# | loss_x     | 0.010979     | 0.024353     |
# | loss_y     | 0.007796     | 0.021750     |
# | loss_w     | 0.012221     | 0.011553     |
# | loss_h     | 0.036268     | 0.016774     |
# | loss_im    | 0.028186     | 0.022125     |
# | loss_re    | 0.015724     | 0.018542     |
# | loss_obj   | 0.314615     | 0.286709     |
# | loss_cls   | 0.012078     | 0.006624     |
# | cls_acc    | 98.28%       | 100.00%      |
# | conf_obj   | 0.894618     | 0.912654     |
# | conf_noobj | 0.001098     | 0.001022     |
# +------------+--------------+--------------+
# Total loss 0.9103209972381592
# ---- ETA 0:05:29.770441
#  99% 359/361 [06:30<00:02,  1.16s/it]
# ---- [Epoch 2/3, Batch 360/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 21           | 42           |
# | loss       | 0.362814     | 0.418596     |
# | loss_x     | 0.006704     | 0.020007     |
# | loss_y     | 0.008278     | 0.026772     |
# | loss_w     | 0.003633     | 0.008274     |
# | loss_h     | 0.005540     | 0.011213     |
# | loss_im    | 0.014766     | 0.011744     |
# | loss_re    | 0.013554     | 0.010246     |
# | loss_obj   | 0.291667     | 0.312938     |
# | loss_cls   | 0.001414     | 0.005166     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.918180     | 0.903795     |
# | conf_noobj | 0.000844     | 0.000963     |
# +------------+--------------+--------------+
# Total loss 0.7814099788665771
# ---- ETA 0:00:02.180005
# 100% 361/361 [06:32<00:00,  1.09s/it]
# Current epoch loss : 0.84690 Saved at /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# 361
#  33% 119/361 [02:05<04:19,  1.07s/it]
# ---- [Epoch 3/3, Batch 120/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 0.288704     | 0.492375     |
# | loss_x     | 0.004067     | 0.010079     |
# | loss_y     | 0.005962     | 0.006847     |
# | loss_w     | 0.002252     | 0.004633     |
# | loss_h     | 0.004731     | 0.007133     |
# | loss_im    | 0.006227     | 0.009445     |
# | loss_re    | 0.006272     | 0.006121     |
# | loss_obj   | 0.255245     | 0.440753     |
# | loss_cls   | 0.000220     | 0.000814     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.917671     | 0.891912     |
# | conf_noobj | 0.000846     | 0.001036     |
# +------------+--------------+--------------+
# Total loss 0.7810788154602051
# ---- ETA 0:30:30.459588
#  66% 239/361 [04:12<02:23,  1.17s/it]
# ---- [Epoch 3/3, Batch 240/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 0.327658     | 0.280737     |
# | loss_x     | 0.004992     | 0.008603     |
# | loss_y     | 0.004933     | 0.008277     |
# | loss_w     | 0.003378     | 0.003477     |
# | loss_h     | 0.004881     | 0.006170     |
# | loss_im    | 0.006103     | 0.004875     |
# | loss_re    | 0.002641     | 0.003892     |
# | loss_obj   | 0.294694     | 0.241251     |
# | loss_cls   | 0.000141     | 0.000953     |
# | cls_acc    | 100.00%      | 100.00%      |
# | conf_obj   | 0.926664     | 0.932119     |
# | conf_noobj | 0.000944     | 0.001013     |
# +------------+--------------+--------------+
# Total loss 0.6083948612213135
# ---- ETA 0:08:43.715422
#  99% 359/361 [06:21<00:02,  1.10s/it]
# ---- [Epoch 3/3, Batch 360/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 22           | 44           |
# | loss       | 0.301317     | 0.472606     |
# | loss_x     | 0.006119     | 0.020931     |
# | loss_y     | 0.009330     | 0.024738     |
# | loss_w     | 0.006183     | 0.014641     |
# | loss_h     | 0.009140     | 0.019277     |
# | loss_im    | 0.010758     | 0.012100     |
# | loss_re    | 0.004264     | 0.003852     |
# | loss_obj   | 0.245393     | 0.349834     |
# | loss_cls   | 0.001264     | 0.018543     |
# | cls_acc    | 100.00%      | 98.75%       |
# | conf_obj   | 0.911703     | 0.895102     |
# | conf_noobj | 0.000903     | 0.001146     |
# +------------+--------------+--------------+
# Total loss 0.7739231586456299
# ---- ETA 0:00:03.243004
# 100% 361/361 [06:22<00:00,  1.06s/it]
# Current epoch loss : 0.79896 Saved at /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
#
# ---- Evaluating Model ----
# Load EVAL samples from dataset/kitti/training
# Done: total EVAL samples 1481
# Detecting objects: 100% 93/93 [01:37<00:00,  1.05s/it]
# Computing AP: 100% 3/3 [00:00<00:00, 175.02it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | Car        | 0.95276 |
# | 1     | Pedestrian | 0.41389 |
# | 2     | Cyclist    | 0.68572 |
# +-------+------------+---------+
# ---- mAP 0.6841189742157366

# %% [markdown]
# # 13. Train YOLO v3-tiny from Darknet Weights

# %%
! python train.py --num_epochs 3 --batch_size 16 --model_def /content/config/complex_yolov3_tiny.cfg --pretrained_path /content/checkpoints/yolov3-tiny.weights --save_path /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# Out:
# cuda
# Load TRAIN samples from dataset/kitti/training
# Done: total TRAIN samples 5763
# /content/checkpoints/yolov3-tiny.weights
# Darknet weight loaded!
# 361
#  33% 119/361 [02:10<04:11,  1.04s/it]
# ---- [Epoch 1/3, Batch 120/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 18           | 36           |
# | loss       | 5.621552     | 49.671886    |
# | loss_x     | 0.137224     | 0.077453     |
# | loss_y     | 0.083226     | 0.083907     |
# | loss_w     | 0.040957     | 0.026358     |
# | loss_h     | 0.096195     | 0.133847     |
# | loss_im    | 0.279476     | 0.268089     |
# | loss_re    | 0.813375     | 1.024895     |
# | loss_obj   | 3.646326     | 47.310093    |
# | loss_cls   | 0.219193     | 0.472525     |
# | cls_acc    | 87.76%       | 88.35%       |
# | conf_obj   | 0.104271     | 0.400953     |
# | conf_noobj | 0.008835     | 0.371021     |
# +------------+--------------+--------------+
# Total loss 55.29343795776367
# ---- ETA 0:04:23.991695
#  66% 239/361 [04:21<02:14,  1.10s/it]
# ---- [Epoch 1/3, Batch 240/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 21           | 42           |
# | loss       | 4.520314     | 40.978821    |
# | loss_x     | 0.111773     | 0.077081     |
# | loss_y     | 0.073208     | 0.088659     |
# | loss_w     | 0.035704     | 0.027933     |
# | loss_h     | 0.072548     | 0.140582     |
# | loss_im    | 0.510018     | 0.504065     |
# | loss_re    | 0.522922     | 0.647274     |
# | loss_obj   | 2.832442     | 38.894638    |
# | loss_cls   | 0.084210     | 0.379369     |
# | cls_acc    | 96.72%       | 95.16%       |
# | conf_obj   | 0.221364     | 0.396826     |
# | conf_noobj | 0.008617     | 0.315627     |
# +------------+--------------+--------------+
# Total loss 45.4991340637207
# ---- ETA 0:02:12.265222
#  99% 359/361 [06:32<00:02,  1.08s/it]
# ---- [Epoch 1/3, Batch 360/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 17           | 34           |
# | loss       | 5.916237     | 39.257938    |
# | loss_x     | 0.086670     | 0.094330     |
# | loss_y     | 0.085684     | 0.083557     |
# | loss_w     | 0.101607     | 0.085753     |
# | loss_h     | 0.220614     | 0.109729     |
# | loss_im    | 0.381802     | 0.392554     |
# | loss_re    | 0.756071     | 0.800347     |
# | loss_obj   | 3.562724     | 36.908752    |
# | loss_cls   | 0.454274     | 0.489570     |
# | cls_acc    | 68.82%       | 74.04%       |
# | conf_obj   | 0.124135     | 0.371952     |
# | conf_noobj | 0.007656     | 0.301416     |
# +------------+--------------+--------------+
# Total loss 45.17417526245117
# ---- ETA 0:00:01.091879
# 100% 361/361 [06:33<00:00,  1.09s/it]
# Current epoch loss : 54.53888 Saved at /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# 361
#  33% 119/361 [02:06<04:06,  1.02s/it]
# ---- [Epoch 2/3, Batch 120/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 21           | 42           |
# | loss       | 4.339288     | 38.204510    |
# | loss_x     | 0.123245     | 0.071668     |
# | loss_y     | 0.082081     | 0.067265     |
# | loss_w     | 0.054593     | 0.055231     |
# | loss_h     | 0.130277     | 0.165581     |
# | loss_im    | 0.326975     | 0.257886     |
# | loss_re    | 0.664295     | 0.729126     |
# | loss_obj   | 2.612201     | 36.219646    |
# | loss_cls   | 0.118493     | 0.378449     |
# | cls_acc    | 93.51%       | 89.74%       |
# | conf_obj   | 0.280449     | 0.423711     |
# | conf_noobj | 0.007733     | 0.297441     |
# +------------+--------------+--------------+
# Total loss 42.54379653930664
# ---- ETA 0:17:26.395356
#  66% 239/361 [04:15<02:10,  1.07s/it]
# ---- [Epoch 2/3, Batch 240/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 5.671268     | 38.217083    |
# | loss_x     | 0.140965     | 0.096642     |
# | loss_y     | 0.109900     | 0.083626     |
# | loss_w     | 0.055733     | 0.031807     |
# | loss_h     | 0.150401     | 0.061045     |
# | loss_im    | 0.238639     | 0.261813     |
# | loss_re    | 0.879329     | 0.845099     |
# | loss_obj   | 3.468029     | 36.171230    |
# | loss_cls   | 0.337933     | 0.394945     |
# | cls_acc    | 63.86%       | 95.29%       |
# | conf_obj   | 0.108759     | 0.385803     |
# | conf_noobj | 0.007903     | 0.296505     |
# +------------+--------------+--------------+
# Total loss 43.88835144042969
# ---- ETA 0:05:27.635979
#  99% 359/361 [06:26<00:02,  1.09s/it]
# ---- [Epoch 2/3, Batch 360/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 22           | 44           |
# | loss       | 4.227561     | 38.289619    |
# | loss_x     | 0.163472     | 0.088952     |
# | loss_y     | 0.080175     | 0.073410     |
# | loss_w     | 0.047490     | 0.034669     |
# | loss_h     | 0.074418     | 0.124680     |
# | loss_im    | 0.304328     | 0.259449     |
# | loss_re    | 0.487311     | 0.907435     |
# | loss_obj   | 2.638662     | 36.149845    |
# | loss_cls   | 0.180110     | 0.388557     |
# | cls_acc    | 93.81%       | 88.66%       |
# | conf_obj   | 0.274824     | 0.404286     |
# | conf_noobj | 0.006996     | 0.296566     |
# +------------+--------------+--------------+
# Total loss 42.517181396484375
# ---- ETA 0:00:02.167976
# 100% 361/361 [06:27<00:00,  1.07s/it]
# Current epoch loss : 43.23065 Saved at /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# 361
#  33% 119/361 [02:09<04:16,  1.06s/it]
# ---- [Epoch 3/3, Batch 120/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 19           | 38           |
# | loss       | 4.759614     | 38.010426    |
# | loss_x     | 0.119493     | 0.077595     |
# | loss_y     | 0.090254     | 0.087238     |
# | loss_w     | 0.077461     | 0.046029     |
# | loss_h     | 0.121045     | 0.098038     |
# | loss_im    | 0.334888     | 0.330384     |
# | loss_re    | 0.601163     | 0.625212     |
# | loss_obj   | 2.944660     | 36.089401    |
# | loss_cls   | 0.257117     | 0.405828     |
# | cls_acc    | 84.62%       | 84.81%       |
# | conf_obj   | 0.234636     | 0.397160     |
# | conf_noobj | 0.007607     | 0.296097     |
# +------------+--------------+--------------+
# Total loss 42.77003860473633
# ---- ETA 0:30:30.955267
#  66% 239/361 [04:17<02:12,  1.09s/it]
# ---- [Epoch 3/3, Batch 240/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 5.135046     | 38.209564    |
# | loss_x     | 0.107302     | 0.100787     |
# | loss_y     | 0.079392     | 0.087841     |
# | loss_w     | 0.051443     | 0.102741     |
# | loss_h     | 0.075120     | 0.111525     |
# | loss_im    | 0.191170     | 0.258489     |
# | loss_re    | 0.610564     | 0.620913     |
# | loss_obj   | 3.414229     | 36.250874    |
# | loss_cls   | 0.304086     | 0.451425     |
# | cls_acc    | 80.82%       | 86.67%       |
# | conf_obj   | 0.113749     | 0.356163     |
# | conf_noobj | 0.007613     | 0.296527     |
# +------------+--------------+--------------+
# Total loss 43.344608306884766
# ---- ETA 0:08:44.089481
#  99% 359/361 [06:26<00:01,  1.00it/s]
# ---- [Epoch 3/3, Batch 360/361] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 8.308999     | 38.057926    |
# | loss_x     | 0.127324     | 0.070412     |
# | loss_y     | 0.080692     | 0.085771     |
# | loss_w     | 0.364571     | 0.063192     |
# | loss_h     | 0.517555     | 0.066589     |
# | loss_im    | 0.725448     | 0.263705     |
# | loss_re    | 1.296738     | 0.741099     |
# | loss_obj   | 3.597678     | 36.098549    |
# | loss_cls   | 0.469323     | 0.418299     |
# | cls_acc    | 67.16%       | 85.07%       |
# | conf_obj   | 0.121593     | 0.386325     |
# | conf_noobj | 0.007528     | 0.295974     |
# +------------+--------------+--------------+
# Total loss 46.36692428588867
# ---- ETA 0:00:03.245897
# 100% 361/361 [06:27<00:00,  1.07s/it]
# Current epoch loss : 42.98080 Saved at /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
#
# ---- Evaluating Model ----
# Load EVAL samples from dataset/kitti/training
# Done: total EVAL samples 1481
# Detecting objects: 100% 93/93 [01:31<00:00,  1.02it/s]
# Computing AP: 100% 3/3 [00:00<00:00, 368.70it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | Car        | 0.04792 |
# | 1     | Pedestrian | 0.00000 |
# | 2     | Cyclist    | 0.00000 |
# +-------+------------+---------+
# ---- mAP 0.015973014590315388
