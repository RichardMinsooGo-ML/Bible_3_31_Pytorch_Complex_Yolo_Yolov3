# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Tue Mar  8 04:57:06 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !pip install terminaltables
# !pip install --upgrade --no-cache-dir gdown

from IPython.display import clear_output 
clear_output()

# Clone from Github Repository
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Pytorch-Complex-Yolo-Yolov3.git
# ! git pull origin master
! git pull origin main
# https://github.com/RichardMinsooGo-ML/Pytorch-Complex-Yolo-Yolov3.git
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 1135, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 1135 (delta 12), reused 0 (delta 0), pack-reused 1113
# Receiving objects: 100% (1135/1135), 734.60 MiB | 34.83 MiB/s, done.
# Resolving deltas: 100% (207/207), done.
# From https://github.com/RichardMinsooGo-ML/Pytorch-Complex-Yolo-Yolov3
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# Checking out files: 100% (1106/1106), done.

# %%
# Download Darknet Weights
# ! wget https://pjreddie.com/media/files/yolo-voc.weights 
! wget https://pjreddie.com/media/files/yolov3-tiny.weights 
! wget https://pjreddie.com/media/files/yolov3.weights
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights 
# ! wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4-tiny.weights

import shutil
shutil.move("/content/yolov3-tiny.weights", "/content/checkpoints")
shutil.move("/content/yolov3.weights", "/content/checkpoints")
# shutil.move("/content/yolov4-tiny.weights", "/content/checkpoints")
# shutil.move("/content/yolov4.weights", "/content/checkpoints") 
% rm -rf sample_data

"""
# Mini-COCO dataset download from Auther's Github repository
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '1jtLdG1SNFo54m8EC_3xYt-gDQQKsNCBR'
output_name = 'coco_10K.zip'
gdown.download(google_path+file_id,output_name,quiet=False)
# https://drive.google.com/file/d/1jtLdG1SNFo54m8EC_3xYt-gDQQKsNCBR/view?usp=sharing
"""
# Out:
# --2022-03-08 04:58:23--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M   100MB/s    in 0.3s
#
# 2022-03-08 04:58:23 (100 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]
#
# --2022-03-08 04:58:23--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   106MB/s    in 2.2s
#
# ...

# %% [markdown]
# ### Pretrained weigth download from Auther's Google Drive

# %%
# Complex Yolo - Yolo V3
# https://drive.google.com/file/d/1jpaDXJcBLf4s3JBYrmapkTQ9OCeGmoQI/view?usp=sharing
import gdown
google_path = 'https://drive.google.com/uc?id='
file_id = '1jpaDXJcBLf4s3JBYrmapkTQ9OCeGmoQI'
output_name = 'Complex_yolo_yolo_v3.pth'
gdown.download(google_path+file_id,output_name,quiet=False)

# Complex Yolo - Yolo V3-tiny
# https://drive.google.com/file/d/1Mukg7aZ3C5ZWFhkS5r1wmL1tgWXsTxS6/view?usp=sharing
google_path = 'https://drive.google.com/uc?id='
file_id = '1Mukg7aZ3C5ZWFhkS5r1wmL1tgWXsTxS6'
output_name = 'Complex_yolo_yolo_v3_tiny.pth'
gdown.download(google_path+file_id,output_name,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jpaDXJcBLf4s3JBYrmapkTQ9OCeGmoQI
# To: /content/Complex_yolo_yolo_v3.pth
# 100%|██████████| 246M/246M [00:01<00:00, 154MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Mukg7aZ3C5ZWFhkS5r1wmL1tgWXsTxS6
# To: /content/Complex_yolo_yolo_v3_tiny.pth
# 100%|██████████| 34.8M/34.8M [00:00<00:00, 128MB/s]
# 'Complex_yolo_yolo_v3_tiny.pth'

# %%
shutil.move("/content/Complex_yolo_yolo_v3.pth", "/content/checkpoints")
shutil.move("/content/Complex_yolo_yolo_v3_tiny.pth", "/content/checkpoints")
# Out:
# '/content/checkpoints/Complex_yolo_yolo_v3_tiny.pth'

# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pwd
# Out:
# /content

# %%
shutil.copy("/content/gdrive/MyDrive/Obj_detection_Torch_3d/Dataset_Kitti/Complex-YOLOv4_Data_2.zip", "/content/Complex-YOLOv4_Data_2.zip")
# !unzip /content/Complex-YOLOv4_Data_2.zip -d /content/
# !rm /content/Complex-YOLOv4_Data_2.zip
clear_output()

# %%
shutil.copy("/content/gdrive/MyDrive/Obj_detection_Torch_3d/Dataset_Kitti/Complex-YOLOv4_Data_1.zip", "/content/Complex-YOLOv4_Data_1.zip")
# !unzip /content/Complex-YOLOv4_Data_1.zip -d /content/
# !rm /content/Complex-YOLOv4_Data_1.zip
clear_output()

# %% [markdown]
# ## Train from pre-trained weight

# %%
# !python train.py --num_epochs 3 --batch_size 8 --pretrained_path /content/checkpoints/Complex_yolo_yolo_v3.pth --save_path /content/checkpoints/Complex_yolo_yolo_v3.pth
# Out:
# Namespace(batch_size=8, checkpoint_freq=2, class_path='dataset/classes.names', evaluation_interval=2, gradient_accumulations=2, img_size=608, model_def='config/complex_yolov3.cfg', multiscale_training=True, n_cpu=1, num_epochs=4, pretrained_path='/content/checkpoints/Complex_yolo_yolo_v3.pth', save_path='/content/checkpoints/Complex_yolo_yolo_v3.pth')
# Trained pytorch weight loaded!
# Load TRAIN samples from dataset/kitti/training
# Done: total TRAIN samples 5763
# 721
#  18% 127/721 [01:55<09:47,  1.01it/s]
# ---- [Epoch 1/4, Batch 128/721] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 21           | 42           | 84           |
# | loss       | 0.242805     | 0.448058     | 0.118771     |
# | loss_x     | 0.003704     | 0.007221     | 0.013017     |
# | loss_y     | 0.002061     | 0.007166     | 0.009502     |
# ...

# %% [markdown]
# ## Train from Darknet weight - Complex Yolo - Yolo V3

# %%
# !python train.py --num_epochs 3 --batch_size 8 --pretrained_path /content/checkpoints/yolov3.weights --save_path /content/checkpoints/Complex_yolo_yolo_v3.pth
# Out:
# Namespace(batch_size=8, checkpoint_freq=2, class_path='dataset/classes.names', evaluation_interval=2, gradient_accumulations=2, img_size=608, model_def='config/complex_yolov3.cfg', multiscale_training=True, n_cpu=1, num_epochs=3, pretrained_path='/content/checkpoints/yolov3.weights', save_path='/content/checkpoints/Complex_yolo_yolo_v3.pth')
# Darknet weight loaded!
# Load TRAIN samples from dataset/kitti/training
# Done: total TRAIN samples 5763
# 721
#  18% 127/721 [01:54<09:11,  1.08it/s]
# ---- [Epoch 1/3, Batch 128/721] ----
# +------------+--------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 | YOLO Layer 2 |
# +------------+--------------+--------------+--------------+
# | grid_size  | 19           | 38           | 76           |
# | loss       | 6.333570     | 36.832397    | 46.876801    |
# | loss_x     | 0.095421     | 0.067359     | 0.079673     |
# | loss_y     | 0.055739     | 0.073592     | 0.072155     |
# ...

# %% [markdown]
# ## Train from pre-trained weight - Complex yolo - Yolo V3-tiny

# %%
# !python train.py --num_epochs 3 --batch_size 32 --model_def /content/config/complex_yolov3_tiny.cfg --pretrained_path /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth --save_path /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# Out:
# Namespace(batch_size=32, checkpoint_freq=2, class_path='dataset/classes.names', evaluation_interval=2, gradient_accumulations=2, img_size=608, model_def='/content/config/complex_yolov3_tiny.cfg', multiscale_training=True, n_cpu=1, num_epochs=3, pretrained_path='/content/checkpoints/Complex_yolo_yolo_v3_tiny.pth', save_path='/content/checkpoints/Complex_yolo_yolo_v3_tiny.pth')
# Trained pytorch weight loaded!
# Load TRAIN samples from dataset/kitti/training
# Done: total TRAIN samples 5763
# 181
#  70% 127/181 [05:00<02:09,  2.40s/it]
# ---- [Epoch 1/3, Batch 128/181] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 18           | 36           |
# | loss       | 0.250184     | 0.353373     |
# | loss_x     | 0.004659     | 0.011773     |
# | loss_y     | 0.007977     | 0.013875     |
# | loss_w     | 0.002456     | 0.005327     |
# ...

# %% [markdown]
# ## Train from Darknet weight - Complex yolo - Yolo V3-tiny

# %%
# !python train.py --num_epochs 3 --batch_size 32 --model_def /content/config/complex_yolov3_tiny.cfg --pretrained_path /content/checkpoints/yolov3-tiny.weights --save_path /content/checkpoints/Complex_yolo_yolo_v3_tiny.pth
# Out:
# Namespace(batch_size=32, checkpoint_freq=2, class_path='dataset/classes.names', evaluation_interval=2, gradient_accumulations=2, img_size=608, model_def='/content/config/complex_yolov3_tiny.cfg', multiscale_training=True, n_cpu=1, num_epochs=3, pretrained_path='/content/checkpoints/yolov3-tiny.weights', save_path='/content/checkpoints/Complex_yolo_yolo_v3_tiny.pth')
# Darknet weight loaded!
# Load TRAIN samples from dataset/kitti/training
# Done: total TRAIN samples 5763
# 181
#  70% 127/181 [04:55<02:03,  2.30s/it]
# ---- [Epoch 1/3, Batch 128/181] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 22           | 44           |
# | loss       | 4.637270     | 48.412830    |
# | loss_x     | 0.125572     | 0.082320     |
# | loss_y     | 0.063515     | 0.077279     |
# | loss_w     | 0.031642     | 0.049711     |
# | loss_h     | 0.065141     | 0.197492     |
# ...
